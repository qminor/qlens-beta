# %% [markdown]
# ### Pre-requisites
# Before running this notebook, you must first have the binary in the same path. To obtain the binary, you can either download the latest or compile it from source.
#
# ##### Compiling from source (Recommended)
# Once you've cloned the repo, compile using `make`. **Python3** is required. When finished, move the binary to same directory as this notebook.

# %%
from qlens import *

# %% [markdown]
# The following are required to allow Jupyter to stream outputs from the terminal.

# %%
# !python3 -m pip install wurlitzer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wurlitzer in /home/ubuntu/.local/lib/python3.6/site-packages (2.0.1)

# %% [markdown]
# ### Initializing
# There are 2 ways to initialize objects in the lenses. The first is to create empty objects then use `initialize` to update specific values

# %%
L = QLens()
A = Alpha()

A.initialize({
    "b": 4.5,
    "alpha": 1,
    "s": 0,
    "q": 0.8,
    "theta": 30,
    "xc": 0.7,
    "yc": 0.3
})

# %% [markdown]
# Or you can pass in all the values when creating. It's up to you which to choose

# %%
S = Shear({
    "shear": 0.02,
    "theta": 10,
    "xc": 0,
    "yc": 0
})

# %%
L.imgdata_read("alphafit.dat")
# Out:
# 'alphafit.dat'

# %% [markdown]
# Here we initialize an `ImageSet` object to extract some data points from QLens:

# %%
I = ImageSet()

# %% [markdown]
# We can set some vary flags on specific lenses themselves.

# %%
A.set_vary_flags([1,0,0,1,1,1,1])

S.set_vary_flags([1,1,0,0])

# %% [markdown]
# ### Adding Lenses
# The `add_lenses` function requires an array of lenses or an array of tuple.

# %%
L.add_lenses([A, S])

# %% [markdown]
# When passing in an array of lenses, default values are chosen for `zl` and `zs` for each of the lenses. So the above is equivalent of:

# %%
L.add_lenses([(A, 0.5, 1), (S, 0.5, 1)])

# %% [markdown]
# ### Running fit
# Once the lenses have been added, we can use the `run_fit` command. First we do some enable some options.

# %%
L.include_flux_chisq(True)
L.use_image_plane_chisq(True)

# %% [markdown]
# We can choose from simplex, powell or twalk. For this example, we're using simplex. The next line is what displays on the terminal.

# %%
# L.run_fit("simplex")

# %% [markdown]
# The following code below is mainly to help us display the output on Jupyter Notebook:

# %%
from wurlitzer import pipes

with pipes() as (out, err):
    L.run_fit("simplex")
    
print(out.read())
# Out:
# Initial stepsizes: 0.45 0.1 20 0.45 0.45 0.03 20 0.45 0.1 20 0.45 0.45 0.03 20
#
# # images: 4 vs. 4 data, chisq_pos=1.77053e+06, chisq_flux=193.998, 2*loglike=1.77073e+06
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 3 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 2 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data, chisq_pos=76756.9, chisq_flux=2588.33, 2*loglike=79345.2
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=2155.73, chisq_flux=201.67, 2*loglike=2357.4
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=935.89, chisq_flux=94.3777, 2*loglike=1030.27
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=224.073, chisq_flux=124.874, 2*loglike=348.947
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=206.927, chisq_flux=105.147, 2*loglike=312.074
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=58.2333, chisq_flux=126.773, 2*loglike=185.006
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=15.5171, chisq_flux=98.9808, 2*loglike=114.498
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=20.9417, chisq_flux=87.1673, 2*loglike=108.109
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=19.9726, chisq_flux=87.9358, 2*loglike=107.908
#
#
#
# Repeating optimization (trial 1)
#
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=87.5923, chisq_flux=116.191, 2*loglike=203.784
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=36.8158, chisq_flux=38.7149, 2*loglike=75.5307
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 6 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data, chisq_pos=18.606, chisq_flux=36.426, 2*loglike=55.032
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data, chisq_pos=9.87449, chisq_flux=30.7429, 2*loglike=40.6174
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=6.19181, chisq_flux=18.8676, 2*loglike=25.0594
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 5 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=3.72303, chisq_flux=9.99134, 2*loglike=13.7144
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=0.458587, chisq_flux=11.0148, 2*loglike=11.4734
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=1.41885, chisq_flux=8.16291, 2*loglike=9.58176
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=1.12768, chisq_flux=6.49583, 2*loglike=7.62351
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=0.512009, chisq_flux=6.91087, 2*loglike=7.42287
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=0.600374, chisq_flux=6.64769, 2*loglike=7.24806
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data
#
# # images: 4 vs. 4 data, chisq_pos=0.781643, chisq_flux=6.44548, 2*loglike=7.22712
#
#
#
# Downhill simplex converged after 1129 iterations
#
# Calculating parameter errors... (press CTRL-C to skip)
#
# Best-fit model: 2*loglike = 7.227119e+00
# 0. alpha(z=0.5): b=4.039, alpha=1, s=0, q=0.887146, theta=67.324 degrees, xc=0.257733, yc=0.184558
# 1. shear(z=0.5): shear=0.0630382, theta_shear=65.2346 degrees, xc=0, yc=0
# 2. alpha(z=0.5): b=1.01342, alpha=1, s=0, q=0.901239, theta=17.6933 degrees, xc=3.3253, yc=0.323492
# 3. shear(z=0.5): shear=0.025372, theta_shear=55.363 degrees, xc=0, yc=0
#
# src0_x=5.404109e-01 src0_y=5.305747e-01 src0_flux=9.088122e-01
#
# Marginalized 1-sigma errors from Fisher matrix:
# b1: 4.039001e+00 +/- 5.395612e-01
# q1: 8.871455e-01 +/- 2.586342e-02
# theta1: 6.732398e+01 +/- 2.882795e+00
# xc1: 2.577329e-01 +/- 1.996155e-01
# yc1: 1.845579e-01 +/- 3.930774e-02
# shear1: 6.303817e-02 +/- 5.511938e-03
# theta_shear1: 6.523465e+01 +/- 6.091098e+00
# b2: 1.013422e+00 +/- 5.126263e-01
# q2: 9.012390e-01 +/- 2.099055e-01
# theta2: 1.769330e+01 +/- 2.083833e+01
# xc2: 3.325297e+00 +/- 8.175382e-01
# yc2: 3.234923e-01 +/- 3.364196e-01
# shear2: 2.537199e-02 +/- 1.187500e-02
# theta_shear2: 5.536119e+01 +/- 7.417458e+00

# %% [markdown]
# We can choose from simplex, powell or twalk. For this example, we're using simplex

# %% [markdown]
# ### Extracting some data

# %%
L.get_imageset(I, 0.5, 0.1, False)

# %% [markdown]
# We can then print some data

# %%
print("\n\nNumber of images: ", I.n_images)
# Out:
# Number of images:  4

# %%
print("src_x: \t\t\tsrc_y: \t\t\tmag:")
for i in I.images:
    print("{}\t{}\t{}".format(i.pos.src()[0], i.pos.src()[1], i.mag))
# Out:
# src_x: 			src_y: 			mag:
# 9.6277070275562	3.2736971328144557	5.894238778531718
# -1.7387184352485605	8.137325635404828	-3.87638946456393
# -8.2051484837532	-3.9650332507330086	4.757639514631689
# 5.051857600587243	-6.963318543531746	-4.4386617800315245
